# %%
from bqplot import *
from bqplot import pyplot as plt 
import bqplot
import numpy as np

# %%
plt.clear()

# %%
x = [9121, 9122, 9123]
y = [8541, 8542, 8543]

# %%
figure = plt.figure()

# %%
figure
# Out:
# Figure(fig_margin={'top': 60, 'bottom': 60, 'left': 60, 'right': 60}, layout=Layout(min_width='125px'), scale_…

# %%
marks = plt.scatter(x, y)
# Out:
# In Axes
# kwargs is {}
# mark is Scatter(colors=['steelblue'], interactions={'hover': 'tooltip'}, scales={'x': LinearScale(), 'y': LinearScale()}, scales_metadata={'x': {'orientation': 'horizontal', 'dimension': 'x'}, 'y': {'orientation': 'vertical', 'dimension': 'y'}, 'color': {'dimension': 'color'}, 'size': {'dimension': 'size'}, 'opacity': {'dimension': 'opacity'}, 'rotation': {'dimension': 'rotation'}, 'skew': {'dimension': 'skew'}}, tooltip_style={'opacity': 0.9}, x=array([9121, 9122, 9123]), y=array([8541, 8542, 8543]))
# options is {}
# About to enter loop scales is {'x': LinearScale(), 'y': LinearScale()}
# fig.axes -> []
# fig_axes = []
#
# In _fetch_axis
# ...

# %%
axes(marks,options=[])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-7fec6ff18ef6> in <module>
# ----> 1 axes(marks,options=[])
#
# TypeError: 'module' object is not callable

# %%
figure.axis_registry
# Out:
# {}

# %%
figure.marks = [marks]

# %%
plt.current_figure()
# Out:
# Figure(axes=[Axis(scale=LinearScale(), side='bottom'), Axis(orientation='vertical', scale=LinearScale(), side=…

# %%
import ipywidgets

# %%
isl = ipywidgets.IntSlider()

# %%
isl
# Out:
# IntSlider(value=0)

# %%
isl.value
# Out:
# 87

# %%
isl.value = 20

# %%
import trace

# %%
import sys

# %%
tracer = trace.Trace(ignoredirs=[sys.prefix,sys.exec_prefix],trace=1,count=0)

# %%
import trace,sys
tracer = trace.Trace(ignoredirs=[sys.prefix,sys.exec_prefix],trace=1,count=0)
tracer.run('isl.value = 55')
# Out:
#  --- modulename: traitlets, funcname: __set__
# traitlets.py(582):         if self.read_only:
# traitlets.py(585):             self.set(obj, value)
#  --- modulename: traitlets, funcname: set
# traitlets.py(559):         new_value = self._validate(obj, value)
#  --- modulename: traitlets, funcname: _validate
# traitlets.py(588):         if value is None and self.allow_none:
# traitlets.py(590):         if hasattr(self, 'validate'):
# traitlets.py(591):             value = self.validate(obj, value)
#  --- modulename: traitlets, funcname: validate
# traitlets.py(1878):         try:
# traitlets.py(1879):             value = int(value)
# traitlets.py(1882):         return _validate_bounds(self, obj, value)
#  --- modulename: traitlets, funcname: _validate_bounds
# traitlets.py(1839):     if trait.min is not None and value < trait.min:
# traitlets.py(1846):     if trait.max is not None and value > trait.max:
# traitlets.py(1853):     return value
# ...
